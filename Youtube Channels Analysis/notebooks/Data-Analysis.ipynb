# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date

# %%
df = pd.read_csv('AI_ML_YT_Videos.csv',index_col=0, header=0)
df.head()
# Out:
#        Channel                                              Title  \
# 0  Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
# 1  Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 2  Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# 3  Jeff Heaton  Creating Certificates to Deploy PyInstaller Py...
# 4  Jeff Heaton  How Should you Architect Your PyTorch Neural N...
#
#   PublishedDate  Views  Likes  Comments
# 0    2023-10-27    764     45         1
# 1    2023-10-26    530     31         1
# 2    2023-10-25    453     29         1
# 3    2023-10-17    439     12         0
# 4    2023-10-12    825     39         1

# %%
len(df)
# Out:
# 6151

# %% [markdown]
# There are 6151 videos in the dataset

# %% [markdown]
# ### Cutting down the dataset to include videos uploaded starting from 2018

# %%
# Convert 'PublishedDate' column to datetime
df['PublishedDate'] = pd.to_datetime(df['PublishedDate']).dt.date

# %%
df.dtypes
# Out:
# Channel          object
# Title            object
# PublishedDate    object
# Views             int64
# Likes             int64
# Comments          int64
# dtype: object

# %%
specific_date = date(2018,1,1)
df_subset = df[df['PublishedDate'] > specific_date]
df_subset
# Out:
#           Channel                                              Title  \
# 0     Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
# 1     Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 2     Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# 3     Jeff Heaton  Creating Certificates to Deploy PyInstaller Py...
# 4     Jeff Heaton  How Should you Architect Your PyTorch Neural N...
# ...           ...                                                ...
# 6141   Krish Naik  Principle Component Analysis (PCA) using sklea...
# 6142   Krish Naik  PySpark Tutorial for Beginners | Apache Spark ...
# 6143   Krish Naik  Creating a Dataset and training an Artificial ...
# 6144   Krish Naik                Artificial Neural Network Intuition
# 6145   Krish Naik  Create an Artifical Neural Network using Keras...
#
#      PublishedDate   Views  Likes  Comments
# 0       2023-10-27     764     45         1
# 1       2023-10-26     530     31         1
# 2       2023-10-25     453     29         1
# 3       2023-10-17     439     12         0
# 4       2023-10-12     825     39         1
# ...            ...     ...    ...       ...
# 6141    2018-07-02  190122   3316       149
# 6142    2018-06-06   39462    613        42
# 6143    2018-02-25   25082    244        34
# 6144    2018-02-24   36519    233         7
# 6145    2018-02-22    9128     88        19
#
# [4081 rows x 6 columns]

# %%
df_subset.to_csv('dataset.csv')

# %% [markdown]
# The new subset dataset contains 4081 rows. A almost ~2000 row cut from the original dataset.

# %%
df_subset.columns
# Out:
# Index(['Channel', 'Title', 'PublishedDate', 'Views', 'Likes', 'Comments'], dtype='object')

# %%
df_subset.dtypes
# Out:
# Channel          object
# Title            object
# PublishedDate    object
# Views             int64
# Likes             int64
# Comments          int64
# dtype: object

# %%
df_subset.isnull().sum()
# Out:
# Channel          0
# Title            0
# PublishedDate    0
# Views            0
# Likes            0
# Comments         0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# Which channel has the oldest video?

# %%
sorted_df_asc = df_subset.sort_values(by='PublishedDate')
sorted_df_asc
# Out:
#              Channel                                              Title  \
# 1622     Siraj Raval                             How Does Cardano Work?
# 1621     Siraj Raval                                    Keras Explained
# 832    Daniel Bourke  Computer Vision Basics + More deeplearning.ai ...
# 3527         Sentdex  Deep Learning - Halite II 2017 Artificial Inte...
# 3526         Sentdex  Training Data - Halite II 2017 Artificial Inte...
# ...              ...                                                ...
# 2        Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# 2842  DeepLearningAI  Mitigating LLM Hallucinations with a Metrics-F...
# 1        Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 4482      Krish Naik  Amazing Langchain Series With End To End Proje...
# 0        Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
#
#      PublishedDate   Views  Likes  Comments
# 1622    2018-01-04   59416   1735       224
# 1621    2018-01-06  244875   4153       231
# 832     2018-01-07     659     22        10
# 3527    2018-01-09   13830    364        38
# 3526    2018-01-10    9682    241        55
# ...            ...     ...    ...       ...
# 2       2023-10-25     453     29         1
# 2842    2023-10-26    8474    457        18
# 1       2023-10-26     530     31         1
# 4482    2023-10-27   15382    462        45
# 0       2023-10-27     764     45         1
#
# [4081 rows x 6 columns]

# %% [markdown]
# `Siraj Raval` has the oldest videos titled `How Does Cardano Work` and `Keras Explained`.Let us now check which channel has the newest upload in the dataset.

# %%
sorted_df_desc = df_subset.sort_values(by='PublishedDate',ascending=False)
sorted_df_desc
# Out:
#              Channel                                              Title  \
# 0        Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
# 4482      Krish Naik  Amazing Langchain Series With End To End Proje...
# 2842  DeepLearningAI  Mitigating LLM Hallucinations with a Metrics-F...
# 1        Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 2        Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# ...              ...                                                ...
# 3526         Sentdex  Training Data - Halite II 2017 Artificial Inte...
# 3527         Sentdex  Deep Learning - Halite II 2017 Artificial Inte...
# 832    Daniel Bourke  Computer Vision Basics + More deeplearning.ai ...
# 1621     Siraj Raval                                    Keras Explained
# 1622     Siraj Raval                             How Does Cardano Work?
#
#      PublishedDate   Views  Likes  Comments
# 0       2023-10-27     764     45         1
# 4482    2023-10-27   15382    462        45
# 2842    2023-10-26    8474    457        18
# 1       2023-10-26     530     31         1
# 2       2023-10-25     453     29         1
# ...            ...     ...    ...       ...
# 3526    2018-01-10    9682    241        55
# 3527    2018-01-09   13830    364        38
# 832     2018-01-07     659     22        10
# 1621    2018-01-06  244875   4153       231
# 1622    2018-01-04   59416   1735       224
#
# [4081 rows x 6 columns]

# %% [markdown]
# `Jedd Heaton` and `Krish Naik` have the newest video uploads.

# %% [markdown]
# ### Which channel has the highest total number of video likes?

# %%
# calculate likes sum, grouped by channel and year:


# Group by 'channelName' and 'Year' and sum the 'Likes'
result = df_subset.groupby(['Channel'])['Likes'].sum().reset_index()

# Rename the columns for clarity
result = result.rename(columns={'Likes': 'TotalLikes'})

result = result.sort_values(by='TotalLikes',ascending=False)
result
# Out:
# /tmp/ipykernel_704593/3734778274.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['PublishedDate'] = pd.to_datetime(df_subset['PublishedDate'])
# /tmp/ipykernel_704593/3734778274.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['Year'] = df_subset['PublishedDate'].dt.year
#                                  Channel  TotalLikes
# 7                             Krish Naik     2024462
# 10                           Siraj Raval      634183
# 9                                Sentdex      583985
# 8                       Nicholas Renotte      415762
# 3                          Daniel Bourke      218351
# 0                      Applied AI Course       94809
# 5                            Jeff Heaton       93613
# 4                         DeepLearningAI       72420
# 6                          Jeremy Howard       68573
# 2                         Arxiv Insights       57618
# 1   Artificial Intelligence — All in One        1161

# %% [markdown]
# `Krish Naik` has the highest total likes count, followed by `Siraj Raval`, and `Sentdex`

# %% [markdown]
# Now, we group by the year as well:

# %%
# Extract the year from the 'PublishedDate' column
df_subset['Year'] = df_subset['PublishedDate'].dt.year

# Group by 'channelName' and 'Year' and sum the 'Likes'
result = df_subset.groupby(['Channel','Year'])['Likes'].sum().reset_index()

# Rename the columns for clarity
result = result.rename(columns={'Likes': 'TotalLikes'})

result = result.sort_values(by=['TotalLikes','Year'],ascending=[False,True])
result
# Out:
# /tmp/ipykernel_704593/3148989746.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['PublishedDate'] = pd.to_datetime(df_subset['PublishedDate'])
# /tmp/ipykernel_704593/3148989746.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['Year'] = df_subset['PublishedDate'].dt.year
#                                  Channel  Year  TotalLikes
# 35                            Krish Naik  2019      661132
# 36                            Krish Naik  2020      570601
# 37                            Krish Naik  2021      397369
# 51                           Siraj Raval  2018      378872
# 38                            Krish Naik  2022      287468
# 52                           Siraj Raval  2019      164823
# 42                      Nicholas Renotte  2021      145190
# 46                               Sentdex  2019      144138
# 45                               Sentdex  2018      139236
# 47                               Sentdex  2020      111730
# 43                      Nicholas Renotte  2022      101756
# 39                            Krish Naik  2023       99626
# 44                      Nicholas Renotte  2023       98652
# 49                               Sentdex  2022       93657
# 12                         Daniel Bourke  2020       71603
# 41                      Nicholas Renotte  2020       68956
# 48                               Sentdex  2021       58175
# 56                           Siraj Raval  2023       50006
# 13                         Daniel Bourke  2021       47130
# 7                         Arxiv Insights  2018       42755
# 11                         Daniel Bourke  2019       42258
# 14                         Daniel Bourke  2022       37551
# 50                               Sentdex  2023       37049
# 3                      Applied AI Course  2021       34628
# 2                      Applied AI Course  2020       33571
# 53                           Siraj Raval  2020       30843
# 23                           Jeff Heaton  2019       26463
# 25                           Jeff Heaton  2021       22048
# 24                           Jeff Heaton  2020       18581
# 30                         Jeremy Howard  2020       18395
# 21                        DeepLearningAI  2023       18002
# 10                         Daniel Bourke  2018       17130
# 32                         Jeremy Howard  2022       16744
# 20                        DeepLearningAI  2022       16248
# 33                         Jeremy Howard  2023       15203
# 26                           Jeff Heaton  2022       14403
# 1                      Applied AI Course  2019       13867
# 19                        DeepLearningAI  2021       13824
# 18                        DeepLearningAI  2020       11558
# 8                         Arxiv Insights  2019       11357
# 27                           Jeff Heaton  2023       11060
# 16                        DeepLearningAI  2018        8973
# 34                            Krish Naik  2018        8266
# 29                         Jeremy Howard  2019        7699
# 28                         Jeremy Howard  2018        6938
# 4                      Applied AI Course  2022        6753
# 0                      Applied AI Course  2018        5884
# 54                           Siraj Raval  2021        5358
# 55                           Siraj Raval  2022        4281
# 17                        DeepLearningAI  2019        3815
# 31                         Jeremy Howard  2021        3594
# 9                         Arxiv Insights  2021        3506
# 15                         Daniel Bourke  2023        2679
# 40                      Nicholas Renotte  2019        1208
# 6   Artificial Intelligence — All in One  2018        1161
# 22                           Jeff Heaton  2018        1058
# 5                      Applied AI Course  2023         106

# %% [markdown]
# This table contains correct information, however, we could convery data in a better way

# %%
# Use pivot_table to pivot the 'Year' values into separate columns
pivoted_result = result.pivot_table(index='Channel', columns='Year', values='TotalLikes', fill_value=0)

# Reset the index to make 'channelName' a regular column
pivoted_result = pivoted_result.reset_index()

# Rename the columns for clarity
pivoted_result.columns.name = None

pivoted_result
# Out:
#                                  Channel      2018      2019      2020  \
# 0                      Applied AI Course    5884.0   13867.0   33571.0
# 1   Artificial Intelligence — All in One    1161.0       0.0       0.0
# 2                         Arxiv Insights   42755.0   11357.0       0.0
# 3                          Daniel Bourke   17130.0   42258.0   71603.0
# 4                         DeepLearningAI    8973.0    3815.0   11558.0
# 5                            Jeff Heaton    1058.0   26463.0   18581.0
# 6                          Jeremy Howard    6938.0    7699.0   18395.0
# 7                             Krish Naik    8266.0  661132.0  570601.0
# 8                       Nicholas Renotte       0.0    1208.0   68956.0
# 9                                Sentdex  139236.0  144138.0  111730.0
# 10                           Siraj Raval  378872.0  164823.0   30843.0
#
#         2021      2022     2023
# 0    34628.0    6753.0    106.0
# 1        0.0       0.0      0.0
# 2     3506.0       0.0      0.0
# 3    47130.0   37551.0   2679.0
# 4    13824.0   16248.0  18002.0
# 5    22048.0   14403.0  11060.0
# 6     3594.0   16744.0  15203.0
# 7   397369.0  287468.0  99626.0
# 8   145190.0  101756.0  98652.0
# 9    58175.0   93657.0  37049.0
# 10    5358.0    4281.0  50006.0

# %% [markdown]
# Some observations:
# - The channel `Artificial Intelligence -- All in One` shows to have no likes count after 2018, which makes sense since the channel stopped uploading videos that same year.
# - `Nicholas Renotte` joined Youtube on January the 26th 2019, hence, no likes count in 2018.
# - Similarily, the channel `Arxiv Insights` having a zero likes count indicate not having video uploads in that same year.

# %%
df_subset.head(5)
# Out:
#        Channel                                              Title  \
# 0  Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
# 1  Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 2  Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# 3  Jeff Heaton  Creating Certificates to Deploy PyInstaller Py...
# 4  Jeff Heaton  How Should you Architect Your PyTorch Neural N...
#
#   PublishedDate  Views  Likes  Comments  Year
# 0    2023-10-27    764     45         1  2023
# 1    2023-10-26    530     31         1  2023
# 2    2023-10-25    453     29         1  2023
# 3    2023-10-17    439     12         0  2023
# 4    2023-10-12    825     39         1  2023

# %%
df_subset.describe()
# Out:
#                        PublishedDate         Views         Likes     Comments  \
# count                           4081  4.081000e+03   4081.000000  4081.000000
# mean   2020-11-14 13:23:27.008086016  4.430436e+04   1045.071551    74.880176
# min              2018-01-04 00:00:00  0.000000e+00      0.000000     0.000000
# 25%              2019-09-14 00:00:00  5.028000e+03    129.000000    11.000000
# 50%              2020-11-01 00:00:00  1.433400e+04    376.000000    33.000000
# 75%              2022-01-21 00:00:00  4.066000e+04   1041.000000    84.000000
# max              2023-10-27 00:00:00  2.689040e+06  64750.000000  3478.000000
# std                              NaN  1.065381e+05   2465.575101   147.497980
#
#               Year
# count  4081.000000
# mean   2020.399167
# min    2018.000000
# 25%    2019.000000
# 50%    2020.000000
# 75%    2022.000000
# max    2023.000000
# std       1.499081

# %%
views_stats_formatted = df_subset.describe()['Views'].apply(lambda x: '{:,.0f}'.format(x))
views_stats_formatted
# Out:
# count        4,081
# mean        44,304
# min              0
# 25%          5,028
# 50%         14,334
# 75%         40,660
# max      2,689,040
# std        106,538
# Name: Views, dtype: object

# %% [markdown]
# Observations:
#
#  - Average view count per video is 44,304 views.
#  - The maximum views count for a video in the dataset is ~2,700,000 views.
#  - 50% of educational AI channels videos get 14,334 views count.
#  - The minimum number of views for a video (strongly) cannot be 0, let us investigate!

# %%
df_subset.loc[df['Views'] == 0]
# Out:
#                Channel                                              Title  \
# 665      Daniel Bourke  Are courses enough for a job? | Machine learni...
# 1360       Siraj Raval                            Siraj Raval Live Stream
# 1493       Siraj Raval                                  All Hands Meeting
# 1501       Siraj Raval                    Quantum Machine Learning (LIVE)
# 1502       Siraj Raval                    Quantum Machine Learning (LIVE)
# 1505       Siraj Raval                    Quantum Machine Learning (LIVE)
# 2019  Nicholas Renotte                       Nicholas Renotte Live Stream
# 2178     Jeremy Howard                          Jeremy Howard Live Stream
# 3028    DeepLearningAI                         DeepLearningAI Live Stream
# 3483           Sentdex           Sentdex Live - Hangout, news, hackerrank
#
#      PublishedDate  Views  Likes  Comments  Year
# 665     2020-10-04      0      0         0  2020
# 1360    2021-12-27      0      0         0  2021
# 1493    2018-10-25      0     45         0  2018
# 1501    2018-10-12      0     19         0  2018
# 1502    2018-10-12      0     14         0  2018
# 1505    2018-10-09      0    121         0  2018
# 2019    2021-01-04      0      0         0  2021
# 2178    2022-04-23      0      0         0  2022
# 3028    2021-03-23      0      0         0  2021
# 3483    2018-06-02      0      0         0  2018

# %% [markdown]
# It seems that Youtube API does not store views count for livestreams as well as comments count.

# %%
df_subset.head()
# Out:
#        Channel                                              Title  \
# 0  Jeff Heaton         LSTM-Based Time Series with PyTorch (10.2)
# 1  Jeff Heaton  Time Series Data Encoding for Deep Learning, P...
# 2  Jeff Heaton  Bayesian Hyperparameter Optimization for PyTor...
# 3  Jeff Heaton  Creating Certificates to Deploy PyInstaller Py...
# 4  Jeff Heaton  How Should you Architect Your PyTorch Neural N...
#
#   PublishedDate  Views  Likes  Comments  Year
# 0    2023-10-27    764     45         1  2023
# 1    2023-10-26    530     31         1  2023
# 2    2023-10-25    453     29         1  2023
# 3    2023-10-17    439     12         0  2023
# 4    2023-10-12    825     39         1  2023

# %% [markdown]
# ### videos' titles analysis using NLTK

# %%
import nltk
nltk.download()
